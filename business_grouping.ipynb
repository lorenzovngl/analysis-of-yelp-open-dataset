# %% [markdown]
# ## Business Grouping

# %%
import pandas as pd

# read the entire file into a python array
with open('yelp_dataset/yelp_academic_dataset_business.json', 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)
data_json_str = "[" + ','.join(data) + "]"

# now, load it into pandas
df = pd.read_json(data_json_str)
df.shape
# Out:
# (209393, 14)

# %%
df.head()
# Out:
#                      address  \
# 0            10913 Bailey Rd
# 1  8880 E Via Linda, Ste 107
# 2      3554 Rue Notre-Dame O
# 3             1015 Sharp Cir
# 4         4827 E Downing Cir
#
#                                           attributes             business_id  \
# 0  {u'BusinessParking': u'{'garage': False, 'stre...  f9NumwFMBDn751xgFiRbNA
# 1  {u'GoodForKids': u'True', u'ByAppointmentOnly'...  Yzvjg0SayhoZgCljUJRF9Q
# 2                                               None  XNoUzKckATkOD1hP6vghZg
# 3  {u'DogsAllowed': u'True', u'BusinessParking': ...  6OAZjbxqM5ol29BuHsil3w
# 4  {u'BusinessAcceptsCreditCards': u'True', u'ByA...  51M2Kk903DFYI6gnB5I6SQ
#
#                                           categories             city  \
# 0  Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...        Cornelius
# 1  Health & Medical, Fitness & Instruction, Yoga,...       Scottsdale
# 2                   Pets, Pet Services, Pet Groomers         Montreal
# 3  Hardware Stores, Home Services, Building Suppl...  North Las Vegas
# 4  Home Services, Plumbing, Electricians, Handyma...             Mesa
#
#                                                hours  is_open   latitude  \
# 0  {u'Monday': u'10:0-18:0', u'Tuesday': u'11:0-2...        1  35.462724
# 1                                               None        1  33.569404
# 2                                               None        1  45.479984
# 3  {u'Friday': u'7:0-16:0', u'Tuesday': u'7:0-16:...        0  36.219728
# 4  {u'Friday': u'9:0-16:0', u'Tuesday': u'9:0-16:...        1  33.428065
#
#     longitude                      name postal_code  review_count  stars state
# 0  -80.852612  The Range At Lake Norman       28031            36    3.5    NC
# 1 -111.890264         Carlos Santo, NMD       85258             4    5.0    AZ
# 2  -73.580070                   Felinus     H4C 1P4             5    5.0    QC
# 3 -115.127725      Nevada House of Hose       89030             3    2.5    NV
# 4 -111.726648   USE MY GUY SERVICES LLC       85205            26    4.5    AZ

# %% [markdown]
# ### Top Rated

# %%
df_las_vegas = df.loc[df['city'] == "Las Vegas"]
df_las_vegas.head()
# Out:
#                                           address  \
# 6                    6870 S Rainbow Blvd, Ste 117
# 16                            3131 Las Vegas Blvd
# 36                           9595 W Tropicana Ave
# 42                            6530 S Decatur Blvd
# 51  101 S Rainbow Blvd, Ste 23, Darby's Hairitage
#
#                                            attributes             business_id  \
# 6   {u'BusinessAcceptsCreditCards': u'True', u'Res...  oiAlXZPIFm2nBCt0DHLu_Q
# 16  {u'BusinessAcceptsCreditCards': u'True', u'Res...  uZuh51lXu7tsrC8RAwkg1A
# 36  {u'Alcohol': u'u'none'', u'Caters': u'False', ...  fnZrZlqW1Z8iWgTVDfv_MA
# 42  {u'BusinessParking': u'{'garage': False, 'stre...  fhNf_sg-XzZ3e7HEVGuOZg
# 51  {u'BusinessAcceptsCreditCards': u'False', u'Re...  5XMKDYmMGSKkCkrYoELxzg
#
#                                            categories       city  \
# 6   Dry Cleaning & Laundry, Local Services, Laundr...  Las Vegas
# 16                     Shopping, Shoe Stores, Fashion  Las Vegas
# 36                    Mexican, Restaurants, Fast Food  Las Vegas
# 42  Burgers, Restaurants, American (Traditional), ...  Las Vegas
# 51          Hair Stylists, Hair Salons, Beauty & Spas  Las Vegas
#
#                                                 hours  is_open   latitude  \
# 6   {u'Monday': u'7:0-19:0', u'Tuesday': u'7:0-19:...        1  36.063977
# 16                                               None        0  36.125732
# 36                                               None        0  36.099738
# 42  {u'Monday': u'11:0-22:0', u'Tuesday': u'11:0-2...        0  36.071196
# 51                                               None        1  36.172534
#
#      longitude                                     name postal_code  \
# 6  -115.241463                     Green World Cleaners       89118
# 16 -115.167608                           Manolo Blahnik       89109
# 36 -115.301568                                Carl's Jr       89147
# 42 -115.207463                    Meat Chix And Wieners       89118
# 51 -115.244762  Annette Thomas Hair Colorist Specialist       89107
#
#     review_count  stars state
# 6             81    3.5    NV
# 16            32    4.5    NV
# 36            15    2.5    NV
# 42            10    3.0    NV
# 51             7    5.0    NV

# %%
c = []
for el in df_las_vegas['categories']:
    for cat in str(el).split(', '):
        if cat not in c:
            c.append(cat)
            
categories = {}
for cat in c:
    categories[cat] = []

for el in df_las_vegas.to_dict('records'):
    if el['categories'] != None:
        for cat in el['categories'].split(', '):
            categories[cat].append(el['name'])
            
categories.keys()[:10]
# Out:
# ['Masonry/Concrete',
#  'Trains',
#  'Anesthesiologists',
#  'Kids Activities',
#  'Truck Rental',
#  'Drugstores',
#  'Dry Cleaning & Laundry',
#  'Well Drilling',
#  'Furniture Rental',
#  'Pawn Shops']
